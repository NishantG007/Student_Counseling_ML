# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the dataset locally

# %%
df=pd.read_csv(r"D:/Programming/Mini Project/Student_Depression/Dataset/Student Depression Dataset.csv")

# %%
df.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
# ...

# %% [markdown]
# # No of Rows (Instances) and Columns (Features)

# %%
df.shape
# Out:
# (27901, 18)

# %%
list(df.columns)
# Out:
# ['id',
#  'Gender',
#  'Age',
#  'City',
#  'Profession',
#  'Academic Pressure',
#  'Work Pressure',
#  'CGPA',
#  'Study Satisfaction',
#  'Job Satisfaction',
#  'Sleep Duration',
#  'Dietary Habits',
#  'Degree',
#  'Have you ever had suicidal thoughts ?',
#  'Work/Study Hours',
#  'Financial Stress',
#  'Family History of Mental Illness',
#  'Depression']

# %% [markdown]
# # Finding missing values in each column

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %% [markdown]
# # Dropping all Instances with null values

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27898.000000  27898.000000       27898.000000   27898.000000
# mean    70442.953402     25.822174           3.141336       0.000430
# std     40642.015063      4.905651           1.381462       0.043994
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35040.750000     21.000000           2.000000       0.000000
# 50%     70689.000000     25.000000           3.000000       0.000000
# 75%    105824.750000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27898.000000        27898.000000      27898.000000      27898.000000
# mean       7.656160            2.943974          0.000681          7.156570
# std        1.470708            1.361122          0.044397          3.707598
# ...

# %%
# Descriptive stats for object (categorical) columns
df.describe(include='object')
# Out:
#        Gender    City Profession     Sleep Duration Dietary Habits    Degree  \
# count   27898   27898      27898              27898          27898     27898
# unique      2      52         14                  5              4        28
# top      Male  Kalyan    Student  Less than 5 hours      Unhealthy  Class 12
# freq    15546    1570      27867               8309          10316      6080
#
#        Have you ever had suicidal thoughts ? Family History of Mental Illness
# count                                  27898                            27898
# unique                                     2                                2
# top                                      Yes                               No
# freq                                   17656                            14397

# %% [markdown]
# # Checking Duplicates

# %%
# Number of duplicate rows
df.duplicated().sum()

# Optionally drop them
# df = df.drop_duplicates()
# Out:
# np.int64(0)

# %%
df.hist(bins=20, figsize=(15, 10), color='skyblue', edgecolor='black')
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %% [markdown]
# Data analytics showed unique values in Column 'Work Pressure' and 'Job Satisfaction', but there frequency

# %%
print(df['Work Pressure'].unique())
print(df['Job Satisfaction'].unique())
# Out:
# [0. 5. 2.]
# [0. 3. 4. 2. 1.]

# %%
# Frequency of unique values in 'Work Pressure'
print("Work Pressure value counts:\n")
print(df['Work Pressure'].value_counts(dropna=False))
print("\n")

# Frequency of unique values in 'Job Satisfaction'
print("Job Satisfaction value counts:\n")
print(df['Job Satisfaction'].value_counts(dropna=False))
print("\n")

print("Age:\n")
print(df['Age'].value_counts(dropna=False))
print("\n")
# Out:
# Work Pressure value counts:
#
# Work Pressure
# 0.0    27895
# 5.0        2
# 2.0        1
# Name: count, dtype: int64
#
#
# Job Satisfaction value counts:
#
# Job Satisfaction
# 0.0    27890
# 2.0        3
# 4.0        2
# 1.0        2
# 3.0        1
# Name: count, dtype: int64
#
#
# Age:
#
# Age
# 24.0    2258
# 20.0    2236
# 28.0    2133
# 29.0    1949
# 33.0    1893
# 25.0    1784
# 21.0    1726
# 23.0    1645
# 18.0    1587
# 19.0    1560
# 34.0    1468
# 27.0    1462
# 31.0    1427
# 32.0    1261
# 22.0    1160
# 26.0    1155
# 30.0    1145
# 35.0      10
# 38.0       8
# 36.0       7
# 42.0       4
# 39.0       3
# 48.0       3
# 46.0       2
# 43.0       2
# 37.0       2
# 44.0       1
# 51.0       1
# 49.0       1
# 58.0       1
# 54.0       1
# 59.0       1
# 56.0       1
# 41.0       1
# Name: count, dtype: int64

# %%
sns.boxplot(x=df['Sleep Duration']) 
plt.title('Boxplot of Sleep Duration') 
plt.show()

# %%
sns.boxplot(x=df['Age']) 
plt.title('Boxplot of Age') 
plt.show()

# %%
sns.boxplot(x=df['Academic Pressure']) 
plt.title('Boxplot of Academic Pressure')
plt.show()

sns.boxplot(x=df['CGPA']) 
plt.title('Boxplot of CGPA')
plt.show()

sns.boxplot(x=df['Degree']) 
plt.title('Boxplot of Degree')
plt.show()


sns.boxplot(x=df['Work/Study Hours']) 
plt.title('Boxplot of Work/Study Hours')
plt.show()

# %%
print("CGPA:\n")
print(df['CGPA'].value_counts(dropna=False))
print("\n")
# Out:
# CGPA:
#
# CGPA
# 8.0400    821
# 9.9600    425
# 5.7400    410
# 8.9500    371
# 9.2100    343
#          ...
# 6.6400      1
# 7.0625      1
# 6.9800      1
# 6.4400      1
# 6.0900      1
# Name: count, Length: 332, dtype: int64

# %%
print("Degree:\n")
print(df['Degree'].value_counts(dropna=False))
print("\n")
# Out:
# Degree:
#
# Degree
# Class 12    6080
# B.Ed        1866
# B.Com       1506
# B.Arch      1478
# BCA         1432
# MSc         1190
# B.Tech      1152
# MCA         1044
# M.Tech      1022
# BHM          925
# BSc          888
# M.Ed         821
# B.Pharm      810
# M.Com        734
# BBA          696
# MBBS         695
# LLB          671
# BE           613
# BA           600
# M.Pharm      582
# MD           572
# MBA          562
# MA           544
# PhD          522
# LLM          482
# MHM          191
# ME           185
# Others        35
# Name: count, dtype: int64

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
# Scatterplot
sns.scatterplot(x='Sleep Duration', y='Age', data=df)
plt.title('Sleep Duration vs Age')
plt.show()

# %%
# Boxplot to compare distributions
sns.boxplot(x='Depression', y='Sleep Duration', data=df)
plt.title('Sleep Duration by Depression Level')
plt.xticks(rotation=45)
plt.show()

# %%
# Countplot with hue
sns.countplot(x='Work Pressure', hue='Depression', data=df)
plt.title('Depression Level across Work Pressure')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness', 'Depression']

# %%
# Select relevant numerical features
selected = ['Sleep Duration', 'Age', 'Depression', 'Financial Stress']
sns.pairplot(df[selected])
plt.suptitle('Pairplot of Selected Numerical Features', y=1.02)
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Finding columns where 95% of the values are same

# %%
# Threshold: 95% of one value
for col in df.columns:
    top_freq = df[col].value_counts(normalize=True, dropna=False).values[0]
    if top_freq > 0.50:
        print(f"{col}: {top_freq:.2%} of one value")
# Out:
# Gender: 55.72% of one value
# Profession: 99.89% of one value
# Work Pressure: 99.99% of one value
# Job Satisfaction: 99.97% of one value
# Have you ever had suicidal thoughts ?: 63.29% of one value
# Family History of Mental Illness: 51.61% of one value
# Depression: 58.55% of one value

# %%
# Drop the specified columns
df.drop(columns=['id', 'City', 'Profession', 'Work Pressure', 'Job Satisfaction', 'Degree'], inplace=True)
# Out:
# C:\Users\xxxni\AppData\Local\Temp\ipykernel_23696\2077176609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['id', 'City', 'Profession', 'Work Pressure', 'Job Satisfaction', 'Degree'], inplace=True)

# %%
df
# Out:
#        Gender   Age  Academic Pressure  CGPA  Study Satisfaction  \
# 0        Male  33.0                5.0  8.97                 2.0
# 1      Female  24.0                2.0  5.90                 5.0
# 2        Male  31.0                3.0  7.03                 5.0
# 3      Female  28.0                3.0  5.59                 2.0
# 4      Female  25.0                4.0  8.13                 3.0
# ...       ...   ...                ...   ...                 ...
# 27896  Female  27.0                5.0  5.75                 5.0
# 27897    Male  27.0                2.0  9.40                 3.0
# 27898    Male  31.0                3.0  6.61                 4.0
# 27899  Female  18.0                5.0  6.88                 2.0
# 27900    Male  27.0                4.0  9.24                 1.0
#
#           Sleep Duration Dietary Habits Have you ever had suicidal thoughts ?  \
# 0              5-6 hours        Healthy                                   Yes
# ...

# %%
df.describe()
# Out:
#                 Age  Academic Pressure          CGPA  Study Satisfaction  \
# count  27898.000000       27898.000000  27898.000000        27898.000000
# mean      25.822174           3.141336      7.656160            2.943974
# std        4.905651           1.381462      1.470708            1.361122
# min       18.000000           0.000000      0.000000            0.000000
# 25%       21.000000           2.000000      6.290000            2.000000
# 50%       25.000000           3.000000      7.770000            3.000000
# 75%       30.000000           4.000000      8.920000            4.000000
# max       59.000000           5.000000     10.000000            5.000000
#
#        Work/Study Hours  Financial Stress    Depression
# count      27898.000000      27898.000000  27898.000000
# mean           7.156570          3.139867      0.585526
# std            3.707598          1.437347      0.492640
# min            0.000000          1.000000      0.000000
# ...

# %%
df.describe(include='object')
# Out:
#        Gender     Sleep Duration Dietary Habits  \
# count   27898              27898          27898
# unique      2                  5              4
# top      Male  Less than 5 hours      Unhealthy
# freq    15546               8309          10316
#
#        Have you ever had suicidal thoughts ? Family History of Mental Illness
# count                                  27898                            27898
# unique                                     2                                2
# top                                      Yes                               No
# freq                                   17656                            14397

# %% [markdown]
# # Unique Value

# %%
unique_counts = df.nunique()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=unique_counts.index, y=unique_counts.values, palette="viridis")

plt.title('Number of Unique Values per Column')
plt.xlabel('Columns')
plt.ylabel('Number of Unique Values')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\xxxni\AppData\Local\Temp\ipykernel_23696\987122835.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=unique_counts.index, y=unique_counts.values, palette="viridis")

# %%
print("Dietary Habits:\n")
print(df['Dietary Habits'].value_counts(dropna=False))
print("\n")
# Out:
# Dietary Habits:
#
# Dietary Habits
# Unhealthy    10316
# Moderate      9921
# Healthy       7649
# Others          12
# Name: count, dtype: int64

# %%
print("Sleep Duration:\n")
print(df['Sleep Duration'].value_counts(dropna=False))
print("\n")
# Out:
# Sleep Duration:
#
# Sleep Duration
# Less than 5 hours    8309
# 7-8 hours            7346
# 5-6 hours            6181
# More than 8 hours    6044
# Others                 18
# Name: count, dtype: int64

# %% [markdown]
# # Label Encoding

# %%
# Drop rows with 'Others' in Dietary Habits (too few and ambiguous)
df = df[df['Dietary Habits'] != 'Others']

# Option 1: Label Encoding (ordinal — if you assume a healthiness order)
diet_map = {'Unhealthy': 0, 'Moderate': 1, 'Healthy': 2}
df['Dietary Habits'] = df['Dietary Habits'].map(diet_map)
# Out:
# C:\Users\xxxni\AppData\Local\Temp\ipykernel_2244\3916996701.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dietary Habits'] = df['Dietary Habits'].map(diet_map)

# %%
# Drop 'Others' entries
df = df[df['Sleep Duration'] != 'Others']

# Ordinal encoding (shorter sleep = less healthy)
sleep_map = {
    'Less than 5 hours': 0,
    '5-6 hours': 1,
    '7-8 hours': 2,
    'More than 8 hours': 3
}
df['Sleep Duration'] = df['Sleep Duration'].map(sleep_map)

# %%
df
# Out:
#        Gender   Age  Academic Pressure  CGPA  Study Satisfaction  \
# 0        Male  33.0                5.0  8.97                 2.0
# 1      Female  24.0                2.0  5.90                 5.0
# 2        Male  31.0                3.0  7.03                 5.0
# 3      Female  28.0                3.0  5.59                 2.0
# 4      Female  25.0                4.0  8.13                 3.0
# ...       ...   ...                ...   ...                 ...
# 27896  Female  27.0                5.0  5.75                 5.0
# 27897    Male  27.0                2.0  9.40                 3.0
# 27898    Male  31.0                3.0  6.61                 4.0
# 27899  Female  18.0                5.0  6.88                 2.0
# 27900    Male  27.0                4.0  9.24                 1.0
#
#        Sleep Duration  Dietary Habits Have you ever had suicidal thoughts ?  \
# 0                   1               2                                   Yes
# ...

# %%
list(df.columns)
# Out:
# ['gender',
#  'age',
#  'academic_pressure',
#  'cgpa',
#  'study_satisfaction',
#  'sleep_duration',
#  'dietary_habits',
#  'have_you_ever_had_suicidal_thoughts_',
#  'work/study_hours',
#  'financial_stress',
#  'family_history_of_mental_illness',
#  'depression']

# %%
# Mapping Yes/No to 1/0
binary_map = {'Yes': 1, 'No': 0}

df['have_you_ever_had_suicidal_thoughts_'] = df['have_you_ever_had_suicidal_thoughts_'].map(binary_map)
df['family_history_of_mental_illness'] = df['family_history_of_mental_illness'].map(binary_map)

# %%
df
# Out:
#        gender   age  academic_pressure  cgpa  study_satisfaction  \
# 0        Male  33.0                5.0  8.97                 2.0
# 1      Female  24.0                2.0  5.90                 5.0
# 2        Male  31.0                3.0  7.03                 5.0
# 3      Female  28.0                3.0  5.59                 2.0
# 4      Female  25.0                4.0  8.13                 3.0
# ...       ...   ...                ...   ...                 ...
# 27896  Female  27.0                5.0  5.75                 5.0
# 27897    Male  27.0                2.0  9.40                 3.0
# 27898    Male  31.0                3.0  6.61                 4.0
# 27899  Female  18.0                5.0  6.88                 2.0
# 27900    Male  27.0                4.0  9.24                 1.0
#
#        sleep_duration  dietary_habits  have_you_ever_had_suicidal_thoughts_  \
# 0                   1               2                                     1
# ...

# %% [markdown]
# # Saving df as a new file

# %%
folder_path = 'D:\Programming\Mini Project\Student_Depression\Dataset'  # change this to your folder path
file_name = 'processed_student_depression.csv'
df.to_csv(folder_path + file_name, index=False)
